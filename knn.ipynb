# %%
import pickle
import sklearn
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils import shuffle
from sklearn import linear_model, preprocessing
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./Car Data Set/car.data")
print(data.head())
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %%
le = preprocessing.LabelEncoder()
buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
persons = le.fit_transform(list(data["persons"]))
door = le.fit_transform(list(data["door"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

# %%
x = list(zip(buying,maint,door,persons,lug_boot,safety))
y = list(cls)

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(x,y,test_size=0.1)
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
acc=knn.score(x_test,y_test)
print(acc)
# Out:
# 0.9421965317919075

# %%
plt.scatter(maint,y)
plt.show()

# %%
names = ["unacc","acc","good","vgood"]
predicted = knn.predict(x_test)
for i in range(len(x_test)):
    print("Predicted value:", names[predicted[i]], "Data:", x_test[i], "Actual",names[y_test[i]])
# Out:
# Predicted value: good Data: (3, 1, 0, 1, 0, 2) Actual unacc
# Predicted value: good Data: (2, 1, 0, 1, 0, 1) Actual good
# Predicted value: good Data: (1, 3, 2, 2, 0, 1) Actual good
# Predicted value: good Data: (3, 0, 2, 0, 1, 2) Actual good
# Predicted value: good Data: (3, 1, 2, 1, 1, 2) Actual unacc
# Predicted value: unacc Data: (3, 2, 2, 2, 0, 2) Actual unacc
# Predicted value: good Data: (1, 0, 2, 0, 1, 2) Actual good
# Predicted value: good Data: (2, 0, 1, 0, 0, 2) Actual good
# Predicted value: good Data: (1, 0, 1, 0, 2, 1) Actual good
# Predicted value: good Data: (3, 0, 4, 2, 1, 0) Actual good
# Predicted value: unacc Data: (0, 1, 3, 2, 0, 2) Actual unacc
# Predicted value: good Data: (0, 2, 1, 1, 2, 1) Actual good
# Predicted value: unacc Data: (1, 0, 0, 1, 0, 2) Actual unacc
# Predicted value: good Data: (0, 3, 0, 1, 1, 1) Actual good
# Predicted value: good Data: (2, 0, 0, 0, 1, 1) Actual good
# Predicted value: good Data: (0, 1, 1, 2, 1, 1) Actual good
# Predicted value: unacc Data: (2, 0, 0, 2, 0, 2) Actual unacc
# Predicted value: good Data: (2, 3, 0, 2, 0, 1) Actual good
# Predicted value: good Data: (0, 2, 0, 2, 2, 2) Actual good
# Predicted value: good Data: (3, 3, 1, 0, 2, 0) Actual good
# Predicted value: good Data: (0, 0, 0, 0, 2, 2) Actual good
# Predicted value: good Data: (3, 3, 2, 1, 2, 1) Actual good
# Predicted value: good Data: (0, 0, 0, 1, 2, 1) Actual good
# Predicted value: good Data: (2, 1, 2, 0, 1, 0) Actual good
# Predicted value: good Data: (2, 0, 0, 1, 2, 2) Actual good
# Predicted value: good Data: (1, 1, 1, 2, 0, 1) Actual good
# Predicted value: good Data: (3, 1, 0, 1, 1, 2) Actual good
# Predicted value: good Data: (2, 0, 0, 2, 2, 0) Actual good
# Predicted value: good Data: (2, 0, 2, 2, 0, 1) Actual good
# Predicted value: unacc Data: (3, 1, 2, 2, 0, 2) Actual unacc
# Predicted value: vgood Data: (1, 2, 2, 2, 0, 0) Actual vgood
# Predicted value: good Data: (0, 0, 0, 1, 1, 1) Actual good
# Predicted value: good Data: (2, 2, 2, 0, 0, 1) Actual good
# Predicted value: good Data: (2, 3, 0, 2, 0, 0) Actual unacc
# Predicted value: good Data: (0, 0, 2, 0, 0, 2) Actual good
# Predicted value: good Data: (0, 2, 1, 1, 2, 2) Actual good
# Predicted value: good Data: (1, 3, 3, 2, 2, 2) Actual good
# Predicted value: acc Data: (1, 2, 0, 1, 1, 0) Actual acc
# Predicted value: good Data: (3, 3, 1, 0, 2, 2) Actual good
# Predicted value: unacc Data: (1, 3, 2, 1, 0, 0) Actual unacc
# Predicted value: good Data: (2, 0, 2, 0, 2, 1) Actual good
# Predicted value: good Data: (0, 2, 0, 0, 1, 2) Actual good
# Predicted value: good Data: (3, 3, 1, 0, 1, 2) Actual good
# Predicted value: good Data: (1, 1, 0, 1, 2, 1) Actual good
# Predicted value: unacc Data: (0, 1, 0, 1, 0, 2) Actual unacc
# Predicted value: good Data: (3, 2, 3, 0, 0, 1) Actual good
# Predicted value: good Data: (0, 1, 0, 0, 1, 1) Actual good
# Predicted value: unacc Data: (1, 2, 3, 2, 2, 0) Actual acc
# Predicted value: unacc Data: (3, 2, 3, 1, 2, 0) Actual unacc
# Predicted value: good Data: (0, 2, 3, 0, 1, 2) Actual good
# Predicted value: good Data: (3, 3, 1, 1, 0, 2) Actual good
# Predicted value: good Data: (3, 3, 1, 1, 2, 0) Actual good
# Predicted value: good Data: (3, 3, 3, 1, 0, 1) Actual good
# Predicted value: unacc Data: (0, 1, 2, 2, 1, 2) Actual unacc
# Predicted value: good Data: (3, 0, 0, 1, 2, 2) Actual good
# Predicted value: unacc Data: (3, 1, 3, 1, 1, 0) Actual unacc
# Predicted value: unacc Data: (3, 2, 3, 2, 1, 2) Actual unacc
# Predicted value: good Data: (0, 1, 0, 0, 0, 0) Actual good
# Predicted value: good Data: (0, 1, 2, 0, 0, 2) Actual good
# Predicted value: good Data: (1, 0, 2, 0, 0, 0) Actual good
# Predicted value: good Data: (1, 1, 0, 0, 2, 0) Actual good
# Predicted value: good Data: (2, 3, 3, 0, 1, 1) Actual good
# Predicted value: good Data: (3, 1, 1, 0, 2, 0) Actual good
# Predicted value: unacc Data: (1, 1, 0, 2, 2, 2) Actual good
# Predicted value: unacc Data: (2, 0, 1, 2, 0, 0) Actual unacc
# Predicted value: good Data: (2, 0, 1, 0, 2, 2) Actual good
# Predicted value: good Data: (0, 0, 2, 0, 1, 1) Actual good
# Predicted value: unacc Data: (2, 3, 0, 2, 0, 2) Actual unacc
# Predicted value: good Data: (3, 0, 0, 1, 2, 0) Actual good
# Predicted value: acc Data: (2, 1, 1, 1, 2, 0) Actual acc
# Predicted value: good Data: (3, 2, 2, 2, 1, 1) Actual good
# Predicted value: good Data: (3, 3, 3, 1, 0, 2) Actual good
# Predicted value: good Data: (1, 1, 0, 1, 0, 1) Actual good
# Predicted value: good Data: (0, 2, 3, 1, 0, 0) Actual unacc
# Predicted value: unacc Data: (1, 0, 3, 2, 1, 2) Actual unacc
# Predicted value: good Data: (3, 3, 3, 2, 1, 0) Actual good
# Predicted value: unacc Data: (2, 3, 2, 2, 2, 0) Actual unacc
# Predicted value: unacc Data: (3, 2, 3, 2, 1, 0) Actual unacc
# Predicted value: good Data: (2, 1, 2, 1, 2, 1) Actual good
# Predicted value: unacc Data: (1, 3, 0, 2, 1, 0) Actual unacc
# Predicted value: good Data: (3, 3, 3, 2, 1, 2) Actual good
# Predicted value: unacc Data: (1, 3, 1, 2, 2, 0) Actual unacc
# Predicted value: good Data: (3, 1, 1, 0, 0, 1) Actual good
# Predicted value: good Data: (3, 1, 1, 1, 1, 2) Actual good
# Predicted value: unacc Data: (1, 1, 0, 1, 2, 2) Actual unacc
# Predicted value: good Data: (3, 2, 1, 2, 1, 1) Actual good
# Predicted value: good Data: (3, 2, 2, 1, 0, 1) Actual good
# Predicted value: good Data: (0, 0, 3, 1, 2, 2) Actual good
# Predicted value: good Data: (0, 3, 0, 2, 1, 2) Actual good
# Predicted value: good Data: (3, 2, 0, 0, 0, 0) Actual good
# Predicted value: good Data: (3, 1, 1, 2, 2, 2) Actual good
# Predicted value: good Data: (2, 3, 0, 0, 2, 0) Actual good
# Predicted value: good Data: (3, 1, 2, 1, 0, 1) Actual good
# Predicted value: good Data: (0, 1, 3, 2, 0, 1) Actual good
# Predicted value: good Data: (3, 0, 0, 2, 2, 2) Actual good
# Predicted value: good Data: (0, 2, 2, 0, 2, 2) Actual good
# Predicted value: good Data: (0, 2, 3, 0, 2, 0) Actual good
# Predicted value: good Data: (3, 0, 2, 0, 0, 1) Actual good
# Predicted value: good Data: (3, 3, 2, 1, 1, 1) Actual good
# Predicted value: good Data: (0, 3, 3, 2, 2, 2) Actual good
# Predicted value: good Data: (3, 3, 0, 0, 0, 0) Actual good
# Predicted value: good Data: (0, 3, 2, 1, 0, 2) Actual good
# Predicted value: good Data: (3, 0, 1, 0, 1, 0) Actual good
# Predicted value: good Data: (0, 0, 0, 1, 2, 2) Actual good
# Predicted value: good Data: (0, 3, 2, 1, 0, 0) Actual good
# Predicted value: good Data: (3, 0, 0, 1, 1, 0) Actual good
# Predicted value: good Data: (2, 0, 2, 0, 0, 1) Actual good
# Predicted value: good Data: (2, 0, 1, 0, 2, 1) Actual good
# Predicted value: good Data: (1, 2, 0, 0, 2, 1) Actual good
# Predicted value: good Data: (3, 0, 1, 2, 1, 2) Actual good
# Predicted value: good Data: (2, 3, 0, 1, 2, 2) Actual good
# Predicted value: good Data: (0, 1, 1, 2, 2, 2) Actual good
# Predicted value: unacc Data: (1, 0, 1, 1, 1, 2) Actual unacc
# Predicted value: good Data: (1, 2, 0, 0, 0, 1) Actual good
# Predicted value: good Data: (0, 0, 1, 1, 0, 1) Actual good
# Predicted value: good Data: (0, 2, 1, 0, 2, 0) Actual good
# Predicted value: unacc Data: (2, 2, 0, 2, 1, 0) Actual unacc
# Predicted value: good Data: (1, 3, 1, 1, 1, 2) Actual good
# Predicted value: good Data: (1, 2, 1, 2, 2, 0) Actual acc
# Predicted value: unacc Data: (2, 0, 1, 1, 0, 2) Actual unacc
# Predicted value: unacc Data: (1, 0, 1, 2, 2, 2) Actual unacc
# Predicted value: good Data: (2, 2, 1, 0, 1, 1) Actual good
# Predicted value: good Data: (3, 2, 0, 1, 2, 2) Actual good
# Predicted value: good Data: (0, 0, 0, 1, 0, 1) Actual good
# Predicted value: good Data: (2, 0, 3, 0, 0, 1) Actual good
# Predicted value: unacc Data: (2, 0, 3, 1, 0, 0) Actual unacc
# Predicted value: good Data: (0, 2, 0, 2, 1, 2) Actual good
# Predicted value: good Data: (2, 3, 2, 1, 1, 1) Actual good
# Predicted value: good Data: (3, 3, 3, 1, 2, 1) Actual good
# Predicted value: good Data: (2, 0, 0, 1, 0, 1) Actual good
# Predicted value: good Data: (2, 2, 0, 2, 2, 1) Actual good
# Predicted value: good Data: (1, 2, 0, 2, 2, 0) Actual good
# Predicted value: vgood Data: (2, 1, 2, 1, 1, 0) Actual vgood
# Predicted value: good Data: (2, 0, 1, 0, 2, 0) Actual good
# Predicted value: good Data: (0, 0, 1, 2, 1, 1) Actual good
# Predicted value: good Data: (0, 2, 2, 0, 1, 2) Actual good
# Predicted value: good Data: (3, 0, 2, 1, 2, 2) Actual good
# Predicted value: unacc Data: (3, 2, 2, 1, 1, 0) Actual unacc
# Predicted value: good Data: (3, 3, 3, 2, 0, 0) Actual good
# Predicted value: unacc Data: (1, 3, 1, 1, 0, 0) Actual unacc
# Predicted value: unacc Data: (2, 1, 0, 2, 0, 2) Actual acc
# Predicted value: good Data: (3, 2, 3, 1, 2, 1) Actual good
# Predicted value: vgood Data: (1, 1, 1, 2, 1, 0) Actual vgood
# Predicted value: good Data: (2, 3, 3, 1, 0, 1) Actual good
# Predicted value: good Data: (3, 0, 1, 2, 0, 2) Actual good
# Predicted value: good Data: (2, 0, 0, 0, 2, 2) Actual good
# Predicted value: unacc Data: (0, 0, 2, 2, 0, 2) Actual unacc
# Predicted value: good Data: (2, 3, 0, 0, 0, 1) Actual good
# Predicted value: good Data: (3, 1, 0, 0, 1, 2) Actual good
# Predicted value: unacc Data: (0, 2, 1, 2, 1, 0) Actual unacc
# Predicted value: good Data: (0, 3, 0, 1, 0, 0) Actual good
# Predicted value: good Data: (3, 2, 3, 0, 2, 2) Actual good
# Predicted value: good Data: (2, 2, 1, 0, 2, 1) Actual good
# Predicted value: good Data: (2, 1, 0, 1, 0, 2) Actual acc
# Predicted value: good Data: (3, 2, 2, 0, 2, 2) Actual good
# Predicted value: good Data: (1, 2, 3, 0, 1, 0) Actual good
# Predicted value: unacc Data: (2, 2, 2, 2, 2, 0) Actual unacc
# Predicted value: unacc Data: (1, 0, 3, 1, 1, 2) Actual unacc
# Predicted value: unacc Data: (1, 3, 3, 2, 1, 2) Actual unacc
# Predicted value: acc Data: (1, 1, 3, 1, 2, 0) Actual acc
# Predicted value: good Data: (1, 3, 3, 2, 1, 1) Actual good
# Predicted value: good Data: (0, 1, 1, 1, 1, 2) Actual good
# Predicted value: good Data: (1, 3, 2, 0, 2, 1) Actual good
# Predicted value: good Data: (1, 3, 2, 1, 2, 2) Actual good
# Predicted value: good Data: (3, 0, 4, 2, 2, 1) Actual good
# Predicted value: good Data: (2, 0, 2, 2, 1, 1) Actual good
# Predicted value: good Data: (0, 1, 2, 0, 1, 2) Actual good
# Predicted value: good Data: (1, 3, 0, 2, 2, 2) Actual good
# Predicted value: good Data: (2, 3, 3, 2, 0, 1) Actual good
# Predicted value: good Data: (1, 3, 3, 0, 2, 2) Actual good
# Predicted value: good Data: (0, 2, 3, 2, 1, 2) Actual unacc
# Predicted value: good Data: (1, 3, 1, 0, 0, 0) Actual good
# Predicted value: good Data: (2, 1, 1, 1, 1, 1) Actual good
